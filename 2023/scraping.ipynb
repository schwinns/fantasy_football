# %%
import pandas as pd

# %%
df = pd.read_html('https://www.nbcsports.com/nfl/matthew-berry/news/matthew-berrys-top-200-fantasy-football-rankings')[0]

# %%
df1 = pd.DataFrame()
df1['Rank'] = df[0].drop(0)
df1['Player'] = df[1].drop(0)

# %%
df1.to_csv('/content/drive/MyDrive/fantasy_football/nbc_matthew_berry.csv', index=False)
